# %% [markdown]
# # Criando lakehouse

# %%
# %sql
CREATE DATABASE IF NOT EXISTS dev.dividas;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS dev.dividas.files;

# %% [markdown]
# #Preapando diretorios

# %%
dbutils.fs.rm("/Volumes/dev/dividas/files/raw", True)
dbutils.fs.rm("/Volumes/dev/dividas/files/checkpoint", True)

dbutils.fs.mkdirs("/Volumes/dev/dividas/files/raw")
dbutils.fs.mkdirs("/Volumes/dev/dividas/files/checkpoint")

# %% [markdown]
# #Obter arquivos testes Incrementais
# - Devido a limitacao de acesso a internet(free account), devemos baixar os conjuntos de dados manualmente
# https://www.bcb.gov.br/conteudo/dadosabertos/BCBPGBCB/DEVEDORES_DIVIDA_ATIVA-2025-06.csv
