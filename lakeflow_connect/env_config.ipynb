# %% [markdown]
# # Criando lakehouse

# %%
# %sql
CREATE DATABASE IF NOT EXISTS lakeflow;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS lakeflow.files;

# %% [markdown]
# #Preapando diretorios

# %%
dbutils.fs.mkdirs("/Volumes/dev/lakeflow/files/raw")
dbutils.fs.mkdirs("/Volumes/dev/lakeflow/files/stage")
dbutils.fs.mkdirs("/Volumes/dev/lakeflow/files/master")

dbutils.fs.rm("/Volumes/dev/lakeflow/files/raw", True)
dbutils.fs.rm("/Volumes/dev/lakeflow/files/stage", True)
dbutils.fs.rm("/Volumes/dev/lakeflow/files/master", True)

# %% [markdown]
# #Obter arquivos testes

# %%
# %sh
curl -v 'https://www.google.com'

# %%
import requests
url = "https://www.bcb.gov.br/conteudo/dadosabertos/BCBPGBCB/DEVEDORES_DIVIDA_ATIVA-2025-06.csv"
r = requests.get(url)

with open("/Volumes/dev/lakeflow/files/raw/DEVEDORES_DIVIDA_ATIVA-2025-06.csv", "wb", encoding='latin-1') as f:
  f.write(r.content)
  
dbutils.fs.ls("/Volumes/dev/lakeflow/files/raw")
