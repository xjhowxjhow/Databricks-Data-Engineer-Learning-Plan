# %%
url_base = "https://www.bcb.gov.br/conteudo/dadosabertos/BCBPGBCB"
caminho_volume = "/Volumes/dev/dividas/files/raw"
list_files = ['DEVEDORES_DIVIDA_ATIVA-2023-12.csv',
              'DEVEDORES_DIVIDA_ATIVA-2024-06.csv',
              'DEVEDORES_DIVIDA_ATIVA-2024-12.csv',
              'DEVEDORES_DIVIDA_ATIVA-2025-06.csv']

# %%
import requests

for file in list_files:
    url = f"{url_base}/{file}"
    response = requests.get(url)
#   with open(f"{caminho_volume}/{file}", "wb") as f:
#       f.write(response.content)
